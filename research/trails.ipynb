# %%
d={"key":"value","key1":"value1"}

# %%
d["key"]
# Out:
# 'value'

# %%
# it will raise an atrribute error because dictionary doesn't have key attribute  
#d.key
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Aaditya\Desktop\Intellipaat\Jupyter_Notebook_Directory\NLP\Text-Summarizer-Project\research\trails.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Aaditya/Desktop/Intellipaat/Jupyter_Notebook_Directory/NLP/Text-Summarizer-Project/research/trails.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> d.key
#
# AttributeError: 'dict' object has no attribute 'key'

# %%
from box import ConfigBox
d2=ConfigBox({"key":"value","key1":"value1"})

# %%
print(d2)
print(d2.key)
# Out:
# {'key': 'value', 'key1': 'value1'}
# value

# %%
from ensure import ensure_annotations

@ensure_annotations
def get_product(x: int,y: int) -> int:
    return x*y

# %%
print("product of x and y is : {}".format(get_product(x=10,y=20)))
# Out:
# product of x and y is : 200

# %%
#will give wrong result with int and str arguments
print(get_product(x=10,y=50))
# Out:
# 500

# %%
import torch
print("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# cpu
